# %% [markdown]
# <a href="https://colab.research.google.com/github/yuki-tamaribuchi/dataprocessing_sample/blob/master/image_fourier_transform_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/drive/MyDrive/photo/LRM_EXPORT_127642476053593_20190812_005259290.jpeg',0)
img=cv2.resize(img,(500,350))

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=500x350 at 0x7F6EF9B46C50>

# %%
width,height=img.shape

# %%
fimg=np.fft.fft2(img)

# %%
cv2_imshow(fimg)
# Out:
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py:22: ComplexWarning: Casting complex values to real discards the imaginary part
#   a = a.clip(0, 255).astype('uint8')
# <PIL.Image.Image image mode=L size=500x350 at 0x7F6EF9249EB8>

# %%
fimg=np.fft.fftshift(fimg)

# %%
cv2_imshow(fimg)
# Out:
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py:22: ComplexWarning: Casting complex values to real discards the imaginary part
#   a = a.clip(0, 255).astype('uint8')
# <PIL.Image.Image image mode=L size=500x350 at 0x7F6EF92590B8>

# %%
dst=np.zeros(img.shape,dtype=complex)

# %%
a=0.2
dst[int(height*(0.5-a)):int(height*(0.5+a)),int(width*(0.5-a)):int(width*(0.5+a))]=fimg[int(height*(0.5-a)):int(height*(0.5+a)), int(width*(0.5-a)):int(width*(0.5+a))]

# %%
dst=np.fft.fftshift(dst)
dst=np.fft.ifft2(dst)
low_img=np.uint8(dst.real)

# %%
cv2_imshow(low_img)
# Out:
# <PIL.Image.Image image mode=L size=500x350 at 0x7F6EF92598D0>
